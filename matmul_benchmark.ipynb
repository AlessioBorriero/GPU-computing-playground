# %%
import tensorflow as tf
import numpy as np
import cupy as cp
import torch
import time

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# Num GPUs Available:  1
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 4930819170366779376
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 377683968
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 9087186723728515198
# physical_device_desc: "device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:41:00.0, compute capability: 8.0"
# xla_global_id: 416903419
# ]

# %%
shape_1 = (3400,7900) # FROM WHERE AND HOW GET THE SETTINGS?
shape_2 = (7900,3400)

tf.random.set_seed(5)
matrix_1_tf = tf.random.normal(shape=shape_1)
matrix_2_tf = tf.random.normal(shape=shape_2)

matrix_1_np = np.random.normal(size=shape_1) 
matrix_2_np = np.random.normal(size=shape_2)

matrix_1_cp = cp.random.normal(size=shape_1) 
matrix_2_cp = cp.random.normal(size=shape_2)

matrix_1_torch = torch.randn(shape_1)
matrix_2_torch = torch.randn(shape_2)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-3-2c511d1bfe32> in <module>
#       4 tf.random.set_seed(5)
#       5 matrix_1_tf = tf.random.normal(shape=shape_1)
# ----> 6 matrix_2_tf = tf.random.normal(shape=shape_2)
#       7
#       8 matrix_1_np = np.random.normal(size=shape_1)
#
# ~/.local/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# ~/.local/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    7105 def raise_from_not_ok_status(e, name):
#    7106   e.message += (" name: " + name if name is not None else "")
# -> 7107   raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#    7108
#    7109
#
# ResourceExhaustedError: failed to allocate memory [Op:AddV2]

# %%
print(matrix_1_tf.device)
print(matrix_1_cp.device)
print(matrix_1_torch.device)
# Out:
# /job:localhost/replica:0/task:0/device:GPU:0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8ee2479d1b31> in <module>
#       1 print(matrix_1_tf.device)
# ----> 2 print(matrix_1_cp.device)
#       3 print(matrix_1_torch.device)
#
# NameError: name 'matrix_1_cp' is not defined

# %%
start_time_tf = time.time()
tf.linalg.matmul(matrix_1_tf, matrix_2_tf)
multiplication_time_tf = time.time() - start_time_tf

start_time_np = time.time()
np.matmul(matrix_1_np, matrix_2_np)
multiplication_time_np = time.time() - start_time_np

start_time_cp = time.time()
cp.matmul(matrix_1_cp, matrix_2_cp)
multiplication_time_cp = time.time() - start_time_cp

# %%
print("Matrix multiplcation time with numpy: {}s" .format(multiplication_time_np))
print("Matrix multiplcation time with cupy: {}s" .format(multiplication_time_cp))
print("Matrix multiplcation time: {}s" .format(multiplication_time_tf))
# Out:
# 0.0005011558532714844 0.2599966526031494 0.0003540515899658203
