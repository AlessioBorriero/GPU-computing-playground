# %%
import cupy as cp
import numpy as np

# %%
N = 100

# %%
q = np.zeros(N, dtype=np.double)
p = cp.zeros(N, dtype=cp.double)

# %%
p.fill(23)

# %%
ran = cp.random.randint(0,N)

# %%
cp.cuda.Device(0).mem_info
# Out:
# (42037608448, 42505273344)
