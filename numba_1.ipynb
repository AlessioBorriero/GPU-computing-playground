# %%
from numba import jit, vectorize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a3b380576455> in <module>
# ----> 1 from numba import jit, vectorize
#
# ModuleNotFoundError: No module named 'numba'

# %%
@jit(nopython=True)
def multiply(p, q):
    m = np.zeros(p.shape)
    for i in range(p.shape):
        m[i] = p[i]*q[i]
    return m

# %%
@vectorize(["float32(float32, float32)"], target='cuda')
def multiply(p, q):
    m = p*q
    return m
# Out:
# /home/borriero/python_develop/venv1/lib64/python3.9/site-packages/numba/cuda/decorators.py:110: NumbaDeprecationWarning: Eager compilation of device functions is deprecated (this occurs when a signature is provided)
#   warn(NumbaDeprecationWarning(msg))

# %%
@vectorize(["float32(float32, float32)"], target='roc')
def multiply(p, q):
    m = p*q
    return m
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/python_develop/venv1/lib64/python3.9/site-packages/numba/np/ufunc/decorators.py in get_target_implementation(cls, kwargs)
#      24         try:
# ---> 25             return cls.target_registry[target]
#      26         except KeyError:
#
# ~/python_develop/venv1/lib64/python3.9/site-packages/numba/core/registry.py in __getitem__(self, item)
#      98             del self.ondemand[item]
# ---> 99         return super(DelayedRegistry, self).__getitem__(item)
#     100
#
# KeyError: 'roc'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_184779/2183825050.py in <module>
#       1 @vectorize(["float32(float32, float32)"], target='roc')
# ----> 2 def multiply(p, q):
#       3     m = p*q
#       4     return m
#
# ~/python_develop/venv1/lib64/python3.9/site-packages/numba/np/ufunc/decorators.py in wrap(func)
#     121
#     122     def wrap(func):
# --> 123         vec = Vectorize(func, **kws)
#     124         for sig in ftylist:
#     125             vec.add(sig)
#
# ~/python_develop/venv1/lib64/python3.9/site-packages/numba/np/ufunc/decorators.py in __new__(cls, func, **kws)
#      35         identity = cls.get_identity(kws)
#      36         cache = cls.get_cache(kws)
# ---> 37         imp = cls.get_target_implementation(kws)
#      38         return imp(func, identity=identity, cache=cache, targetoptions=kws)
#      39
#
# ~/python_develop/venv1/lib64/python3.9/site-packages/numba/np/ufunc/decorators.py in get_target_implementation(cls, kwargs)
#      25             return cls.target_registry[target]
#      26         except KeyError:
# ---> 27             raise ValueError("Unsupported target: %s" % target)
#      28
#      29
#
# ValueError: Unsupported target: roc
